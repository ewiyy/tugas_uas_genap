# %% [markdown]
# <a href="https://colab.research.google.com/github/ewiyy/tugas_uas_genap/blob/main/dewie_carolline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import time

# o = obat (disingkat pada variabel)
data_obat = []  # list untuk menyimpan data obat

# simpan data ke file
def simpan_data():
    with open("inventori_apotek.json", "w") as f:
        json.dump(data_obat, f)

# muat data dari file
def muat_data():
    try:
        with open("inventori_apotek.json", "r") as f:
            return json.load(f)
    except:
        return []

# cari obat berdasarkan kode
def cari_obat(kode):
    for o in data_obat:
        if o['kode'] == kode:
            return o
    return None

# """" MENU UTAMA """"

def tambah_obat():
    kode = input("Kode obat: ")
    if cari_obat(kode):
        print("Obat dengan kode ini sudah ada.\n")
        return
    nama = input("Nama obat: ")
    stok = int(input("Jumlah stok: "))
    data_obat.append({"kode": kode, "nama": nama, "stok": stok})
    print("Obat berhasil ditambahkan.\n")

def lihat_semua():
    if not data_obat:
        print("Belum ada data obat.\n")
        return
    start = time.time()
    for o in data_obat:
        print(f"{o['kode']} - {o['nama']} (Stok: {o['stok']})")
    end = time.time()
    print(f"Waktu tampilkan data: {end - start:.6f} detik\n")

def edit_stok():
    kode = input("Masukkan kode obat yang ingin diedit: ")
    o = cari_obat(kode)
    if o:
        o['stok'] = int(input("Stok baru: "))
        print("Stok obat diperbarui.\n")
    else:
        print("Obat tidak ditemukan.\n")

def hapus_obat():
    kode = input("Masukkan kode obat yang ingin dihapus: ")
    o = cari_obat(kode)
    if o:
        data_obat.remove(o)
        print("Obat berhasil dihapus.\n")
    else:
        print("Obat tidak ditemukan.\n")

def laporan_stok():
    if not data_obat:
        print("Belum ada data obat.\n")
        return
    print("Laporan stok obat (diurutkan dari jumlah terbanyak):")
    start = time.time()
    urut = sorted(data_obat, key=lambda x: x['stok'], reverse=True)
    for o in urut:
        print(f"{o['nama']} - Stok: {o['stok']}")
    end = time.time()
    print(f"Waktu proses laporan: {end - start:.6f} detik\n")

# """" PROGRAM UTAMA """"
data_obat = muat_data()

while True:
    print("=== Menu Inventori Toko Apotek ===")
    print("1. Tambah Obat")
    print("2. Lihat Semua Obat")
    print("3. Edit Stok Obat")
    print("4. Hapus Obat")
    print("5. Laporan Stok")
    print("6. Simpan & Keluar")

    pilihan = input("Pilih menu (1-6): ")
    print()

    if pilihan == '1':
        tambah_obat()
    elif pilihan == '2':
        lihat_semua()
    elif pilihan == '3':
        edit_stok()
    elif pilihan == '4':
        hapus_obat()
    elif pilihan == '5':
        laporan_stok()
    elif pilihan == '6':
        simpan_data()
        print("Data disimpan. Keluar dari program.")
        break
    else:
        print("Pilihan tidak valid.\n")
# Out:
# === Menu Inventori Toko Apotek ===
# 1. Tambah Obat
# 2. Lihat Semua Obat
# 3. Edit Stok Obat
# 4. Hapus Obat
# 5. Laporan Stok
# 6. Simpan & Keluar
# Pilih menu (1-6): 1
#
# Kode obat: OBT001
# Nama obat: Paracetamol
# Jumlah stok: 100
# Obat berhasil ditambahkan.
#
# === Menu Inventori Toko Apotek ===
# 1. Tambah Obat
# 2. Lihat Semua Obat
# 3. Edit Stok Obat
# 4. Hapus Obat
# 5. Laporan Stok
# 6. Simpan & Keluar
# Pilih menu (1-6): 1
#
# Kode obat: OBT002
# Nama obat: Bodrex Extra
# Jumlah stok: 150
# Obat berhasil ditambahkan.
#
# === Menu Inventori Toko Apotek ===
# 1. Tambah Obat
# 2. Lihat Semua Obat
# 3. Edit Stok Obat
# 4. Hapus Obat
# 5. Laporan Stok
# 6. Simpan & Keluar
# Pilih menu (1-6): 1
#
# Kode obat: OBT003
# Nama obat: Ponstan
# Jumlah stok: 200
# Obat berhasil ditambahkan.
#
# === Menu Inventori Toko Apotek ===
# 1. Tambah Obat
# 2. Lihat Semua Obat
# 3. Edit Stok Obat
# 4. Hapus Obat
# 5. Laporan Stok
# 6. Simpan & Keluar
# Pilih menu (1-6): 1
#
# Kode obat: OBT004
# Nama obat: Insto Reguler
# Jumlah stok: 155
# Obat berhasil ditambahkan.
#
# === Menu Inventori Toko Apotek ===
# 1. Tambah Obat
# 2. Lihat Semua Obat
# 3. Edit Stok Obat
# 4. Hapus Obat
# 5. Laporan Stok
# 6. Simpan & Keluar
# Pilih menu (1-6): 2
#
# OBT001 - Paracetamol (Stok: 100)
# OBT002 - Bodrex Extra (Stok: 150)
# OBT003 - Ponstan (Stok: 200)
# OBT004 - Insto Reguler (Stok: 155)
# Waktu tampilkan data: 0.000029 detik
#
# === Menu Inventori Toko Apotek ===
# 1. Tambah Obat
# 2. Lihat Semua Obat
# 3. Edit Stok Obat
# 4. Hapus Obat
# 5. Laporan Stok
# 6. Simpan & Keluar
# Pilih menu (1-6): 3
#
# Masukkan kode obat yang ingin diedit: OBT001
# Stok baru: 50
# Stok obat diperbarui.
#
# === Menu Inventori Toko Apotek ===
# 1. Tambah Obat
# 2. Lihat Semua Obat
# 3. Edit Stok Obat
# 4. Hapus Obat
# 5. Laporan Stok
# 6. Simpan & Keluar
# Pilih menu (1-6): 4
#
# Masukkan kode obat yang ingin dihapus: OBT004
# Obat berhasil dihapus.
#
# === Menu Inventori Toko Apotek ===
# 1. Tambah Obat
# 2. Lihat Semua Obat
# 3. Edit Stok Obat
# 4. Hapus Obat
# 5. Laporan Stok
# 6. Simpan & Keluar
# Pilih menu (1-6): 5
#
# Laporan stok obat (diurutkan dari jumlah terbanyak):
# Ponstan - Stok: 200
# Bodrex Extra - Stok: 150
# Paracetamol - Stok: 50
# Waktu proses laporan: 0.000027 detik
#
# === Menu Inventori Toko Apotek ===
# 1. Tambah Obat
# 2. Lihat Semua Obat
# 3. Edit Stok Obat
# 4. Hapus Obat
# 5. Laporan Stok
# 6. Simpan & Keluar
# Pilih menu (1-6): 6
#
# Data disimpan. Keluar dari program.
